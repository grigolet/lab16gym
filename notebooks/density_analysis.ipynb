 6.25E-10, 6.17E-10, 6.02E-10, 5.73E-10, 5.30E-10, 4.96E-10, 4.59E-10, 4.15E-10,
 3.84E-10, 3.43E-10, 2.94E-10, 2.64E-10, 2.35E-10,
 5.46E-37, 7.76E-28, 1.52E-20, 1.99E-17, 4.28E-15, 2.70E-13, 2.11E-12, 1.62E-11,
 8.09E-11, 1.59E-10, 2.60E-10, 3.72E-10, 4.38E-10, 5.11E-10, 5.73E-10, 5.95E-10,
 6.03E-10, 5.96E-10, 5.83E-10, 5.56E-10, 5.16E-10, 4.84E-10, 4.48E-10, 4.06E-10,
 3.77E-10, 3.36E-10, 2.89E-10, 2.60E-10, 2.32E-10,
 5.47E-37, 7.70E-28, 1.49E-20, 1.93E-17, 4.08E-15, 2.55E-13, 1.97E-12, 1.50E-11,
 7.43E-11, 1.46E-10, 2.38E-10, 3.40E-10, 4.01E-10, 4.70E-10, 5.28E-10, 5.50E-10,
 5.60E-10, 5.57E-10, 5.46E-10, 5.24E-10, 4.89E-10, 4.60E-10, 4.28E-10, 3.89E-10,
 3.62E-10, 3.25E-10, 2.80E-10, 2.52E-10, 2.25E-10
]).reshape(29, 6)
X[1]
#plt.plot(t, X[0])
#plt.plot(t, X[1])
#plt.plot(t, X[2])
#plt.plot(t, X[3])
#plt.plot(t, X[4])
#plt.plot(t, X[5])

#plt.plot(t, X_6[0]/X_486[0])
#plt.plot(t, X_6[1]/X_486[1])
#plt.plot(t, X_6[2]/X_486[2])
#plt.plot(t, X_6[3]/X_486[3])
#plt.plot(t, X_6[4]/X_486[4])
#plt.plot(t, X_6[5]/X_486[5])

plt.plot(n, X_6[0]/X_486[0])
plt.plot(n, X_6[1]/X_486[1])
plt.plot(n, X_6[2]/X_486[2])
plt.plot(n, X_6[3]/X_486[3])
plt.plot(n, X_6[4]/X_486[4])
plt.plot(n, X_6[5]/X_486[5])
plt.plot(n, X_6[6]/X_486[6])
plt.plot(n, X_6[7]/X_486[7])
plt.plot(n, X_6[8]/X_486[8])
plt.plot(n, X_6[9]/X_486[9])
plt.plot(n, X_6[10]/X_486[10])
plt.plot(n, X_6[11]/X_486[11])
plt.plot(n, X_6[12]/X_486[12])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ba0e110a9aee> in <module>()
#      60  3.62E-10, 3.25E-10, 2.80E-10, 2.52E-10, 2.25E-10
#      61 ]).reshape(29, 6)
# ---> 62 X[1]
#      63 #plt.plot(t, X[0])
#      64 #plt.plot(t, X[1])
#
# NameError: name 'X' is not defined

# %%
X_6[9]/X_486[9]
# Out:
# array([  4.2776204 ,   4.2384106 ,   4.20664207,   4.19087137,
#         80.58608059,  27.94871795])
