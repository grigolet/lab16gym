# %%
import sys
sys.path.append('../langmuir/')
import gymness.aggregate as agg
import gymness.campoB as cb

# %%
# reading fit results
df = agg.aggregate_data('../langmuir/data/data-2702')
df
# Out:
# Reading dataset:['2702lang02', '2702lang04', '2702lang03', '2702lang01', '2702lang05']
#            id  probe  x  I_B         P  W_em     P_off       T_e   err_T_e  \
# 0  2702lang02      1  0  600  0.000432    40  0.000173  6.998732  0.027666
# 1  2702lang04      1  0  600  0.000432    60  0.000173  6.430804  0.020512
# 2  2702lang03      1  0  600  0.000432    40  0.000173  6.978377  0.027097
# 3  2702lang01      1  0  600  0.000415    20  0.000173  5.380305  0.059105
# 4  2702lang05      1  0  600  0.000434    60  0.000173  6.607577  0.069426
#
#             n_e     ...          err_f_ep   v_plasma  err_v_plasma     alpha  \
# 0  8.401558e+16     ...      5.407723e-14  16.426062      0.109834  0.008359
# 1  8.330331e+16     ...      3.858864e-14  16.349827      0.081801  0.009292
# 2  8.495108e+16     ...      5.263380e-14  16.480186      0.107335  0.008159
# 3  5.946621e+16     ...      1.146133e-13  13.500571      0.212483  0.010466
# 4  8.589258e+16     ...      9.265364e-14  16.816468      0.231244  0.007290
#
#    err_alpha  v_floating  err_v_floating  i_ionic_sat  err_i_ionic_sat  \
# 0   0.000235   -4.570135        0.026837    -0.001849         0.000011
# 1   0.000153   -2.942586        0.020264    -0.001758         0.000007
# 2   0.000228   -4.454946        0.026045    -0.001867         0.000010
# 3   0.000234   -2.640346        0.035169    -0.001148         0.000007
# 4   0.000219   -3.006263        0.022966    -0.001837         0.000011
#
#         j_sat
# 0 -154.116458
# 1 -146.478667
# 2 -155.605752
# 3  -95.643015
# 4 -153.093338
#
# [5 rows x 22 columns]

# %%
a = df.groupby(['P_off', 'W_em'])['n_e', 'err_n_e', 'T_e', 'err_T_e'].mean()
a
# Out:
#                         n_e       err_n_e       T_e   err_T_e
# P_off    W_em
# 0.000173 20    5.946621e+16  3.701640e+11  5.380305  0.059105
#          40    8.448333e+16  2.917734e+11  6.988555  0.027381
#          60    8.459794e+16  3.630466e+11  6.519191  0.044969
